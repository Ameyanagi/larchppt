# %%
test = ["test", "test"]
print(test)
# Out:
# ['test', 'test']

# %%
a = test

# %%
a.append("test")

# %%
print(a)
print(test)
# Out:
# ['test', 'test', 'test']
# ['test', 'test', 'test']

# %%
data_path = "/Users/ryuichi/analysis/20230302/Co/Co14-JB Co K  0001.dat"

# %%
import numpy as np

# %%
test = np.loadtxt(data_path)

# %%
test
# Out:
# array([[ 7.51919759e+03,  1.16740700e+00,  4.88307300e-01, ...,
#         -1.11262500e-06,  1.85645900e-06, -2.74543600e-05],
#        [ 7.52419759e+03,  2.31048900e+00,  9.69034000e-01, ...,
#         -2.19802900e-06,  4.46661500e-06, -5.84059000e-05],
#        [ 7.52919759e+03,  2.32859900e+00,  9.80507200e-01, ...,
#         -7.26272600e-06,  1.32019600e-05, -4.63754300e-05],
#        ...,
#        [ 8.66496489e+03,  1.78378100e+00,  1.45187800e+00, ...,
#         -2.13056300e-05,  7.27106100e-06, -5.01258500e-05],
#        [ 8.66979904e+03,  1.76171200e+00,  1.43684400e+00, ...,
#         -1.82138100e-05,  7.51916700e-06, -5.00804400e-05],
#        [ 8.67464538e+03,  7.25711800e-01,  5.92764300e-01, ...,
#         -1.03613200e-05,  4.27243300e-06, -2.18931700e-05]])

# %%
with open(data_path) as f:
    lines = f.read()
    print(lines)
# Out:
# # Facility: NSLS-II
# # Beamline: QAS
# # Year: 2023
# # Cycle: 1
# # SAF: 310849
# # PI: Frenkel
# # Proposal: 310164
# # Scan ID: 166005
# # UID: 710f3879-83e7-45ed-bcad-9717478928a1
# # Comment:
# # Start time: 03/03/2023  04:39:31
# # Stop time: 03/03/2023  04:40:04
# # Total time: 00:32
# # Trajectory name: Co-30s-7709.txt
# # Element: Cobalt ( 27)
# # Edge: K
# # E0: 7709
# # Reference Foil Element: Co
# # Keithley Gains I0: 1E7 V/A It: 1E7 V/A Iref: 1E7 V/A PIPS: 1E8 V/A
# # Ion Chamber Gas Flow Rates: I0: 69.80 sccm He + 29.70 sccm N2 + 0.00 sccm Ar
# # Ion Chamber Gas Flow Rates: It&Iref: 99.80 sccm N2 + 0.00 sccm Ar
# # Incident Beam Path Vertical: 31.33 mm
# # Incident Slits Positions B: TOP: 1.9999937499999998 mm Bottom: 1.0 mm Inboard: 0.5770625 mm Outboard: 1.5770625 mm
# # Sample Stage Positions: Rotation: 45.0 deg Horizontal: 4.05 mm Vertical: -14.55 mm Beam Direction: 0.00 mm
# # PerkinElmer Vertical Position: 500.00 mm
# ...

# %%
import matplotlib.pyplot as plt

# %%
plt.plot(test[:,0], test[:,1])
plt.plot(test[:,0], test[:,4])

# %%
plt.plot(test[:,0], test[:,4]/test[:,1]+test[:,1]*0.00)
