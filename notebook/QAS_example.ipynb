# %%
import os
import sys
module_path = os.path.abspath(os.path.join('..'))
if module_path not in sys.path:
    sys.path.append(module_path)

# %%
# !pip install python-pptx
# Out:
# Requirement already satisfied: python-pptx in /Users/ryuichi/mambaforge/envs/larch/lib/python3.9/site-packages (0.6.21)
# Requirement already satisfied: XlsxWriter>=0.5.7 in /Users/ryuichi/mambaforge/envs/larch/lib/python3.9/site-packages (from python-pptx) (3.0.3)
# Requirement already satisfied: Pillow>=3.3.2 in /Users/ryuichi/mambaforge/envs/larch/lib/python3.9/site-packages (from python-pptx) (9.1.1)
# Requirement already satisfied: lxml>=3.1.0 in /Users/ryuichi/mambaforge/envs/larch/lib/python3.9/site-packages (from python-pptx) (4.9.0)

# %%
import larchppt

# %%
lp = larchppt.larchppt()

# %%
data_dir = "/nsls2/data/qas-new/legacy/processed/2022/2/{}/{}*.dat"
proposal = 309890

# %%
lp.QAS_preanalysis(files_path=data_dir.format(proposal, "Co11"), output_dir="../output/Co11/", athena_output_dir="../output/Co11/")

# %%
lp.generate_presenation(output_dir="../output/Co11/", ppt_path="../output/Co11_preanalysis.pptx")

# %%
import os
import sys
module_path = os.path.abspath(os.path.join('..'))
if module_path not in sys.path:
    sys.path.append(module_path)

# %%
import autoQAS

# %%
aq = autoQAS.autoQAS(debug_dir="../Co11/data/")

# %%
aq.watch_QAS()
# Out:
# File modified: /Users/ryuichi/python/larchppt/Co11/data/Co11 Co-C-MA-1-Co-800-7 powder on kapton tape Co  0022.dat
# 100%|██████████| 14/14 [00:00<00:00, 39.71it/s]

# %%
aq.show_img("/Users/ryuichi/python/larchppt/output/Co11 Co-C-MA-1-Co-800-7 powder on kapton tape Co/00000_ All Spectrum/fig/*.png")

# %%
aq.watch_update()

# %%
name = "Co9 Co-C-MA-2-Co-20-5 powder on kapton tape Co  0004.dat"
name2 = "Co11 Co-C-MA-1-Co-800-7 powder on kapton tape Co  0128-r0001.dat"

# %%
import re

# %%
name_regex = re.compile(r'(.*)  [0-9]{4}(?:-r[0-9]{4}\.dat)?')

# %%
print(re.findall(name_regex, name))
print(re.findall(name_regex, name2))

# %%
from IPython.display import clear_output
import time

for i in range(10):
    clear_output(wait=True)
    print(i, flush=True)
    time.sleep(1)

# %%
# !pip list
# Out:
# Package                       Version
# ----------------------------- ---------
# algopy                        0.5.7
# appnope                       0.1.3
# asteval                       0.9.27
# asttokens                     2.0.5
# attrs                         21.4.0
# autopep8                      1.6.0
# backcall                      0.2.0
# backports.functools-lru-cache 1.6.4
# certifi                       2022.6.15
# charset-normalizer            2.0.12
# cycler                        0.11.0
# debugpy                       1.6.0
# decorator                     5.1.1
# entrypoints                   0.4
# executing                     0.8.3
# fabio                         0.14.0
# fonttools                     4.33.3
# future                        0.18.2
# h5py                          3.7.0
# hdf5plugin                    3.3.1
# idna                          3.3
# imageio                       2.19.3
# iniconfig                     1.1.1
# ipykernel                     6.15.0
# ipython                       8.4.0
# jedi                          0.18.1
# joblib                        1.1.0
# jupyter-client                7.3.4
# jupyter-core                  4.10.0
# kiwisolver                    1.4.3
# latexcodec                    2.0.1
# lmfit                         1.0.3
# lxml                          4.9.0
# matplotlib                    3.5.2
# matplotlib-inline             0.1.3
# monty                         2022.4.26
# mpmath                        1.2.1
# nest-asyncio                  1.5.5
# networkx                      2.8.4
# numdifftools                  0.9.40
# numexpr                       2.8.1
# numpy                         1.23.0
# opencv-python                 4.6.0.66
# packaging                     21.3
# palettable                    3.3.0
# pandas                        1.4.3
# parso                         0.8.3
# patsy                         0.5.2
# PeakUtils                     1.3.3
# pexpect                       4.8.0
# pickleshare                   0.7.5
# Pillow                        9.1.1
# pip                           22.1.2
# plotly                        5.8.2
# pluggy                        1.0.0
# prompt-toolkit                3.0.29
# psutil                        5.9.1
# ptyprocess                    0.7.0
# pure-eval                     0.2.2
# py                            1.11.0
# pybtex                        0.24.0
# PyCifRW                       4.4.3
# pycodestyle                   2.8.0
# pyFAI                         0.21.3
# Pygments                      2.12.0
# pymatgen                      2022.5.26
# pyparsing                     3.0.9
# pyshortcuts                   1.8.2
# pytest                        7.1.2
# python-dateutil               2.8.2
# python-pptx                   0.6.21
# pytz                          2022.1
# PyWavelets                    1.3.0
# PyYAML                        6.0
# pyzmq                         23.1.0
# requests                      2.28.0
# ruamel.yaml                   0.17.21
# ruamel.yaml.clib              0.2.6
# scikit-image                  0.19.3
# scikit-learn                  1.1.1
# scipy                         1.8.1
# seaborn                       0.11.2
# setuptools                    59.8.0
# silx                          1.0.0
# six                           1.16.0
# spglib                        1.16.5
# SQLAlchemy                    1.4.38
# stack-data                    0.3.0
# statsmodels                   0.13.2
# sympy                         1.10.1
# tabulate                      0.8.10
# tenacity                      8.0.1
# termcolor                     1.1.0
# threadpoolctl                 3.1.0
# tifffile                      2022.5.4
# toml                          0.10.2
# tomli                         2.0.1
# tornado                       6.1
# tqdm                          4.64.0
# traitlets                     5.3.0
# uncertainties                 3.1.7
# urllib3                       1.26.9
# watchdog                      2.1.9
# wcwidth                       0.2.5
# wheel                         0.37.1
# XlsxWriter                    3.0.3
# xraydb                        4.4.7
# xraylarch                     0.9.64
